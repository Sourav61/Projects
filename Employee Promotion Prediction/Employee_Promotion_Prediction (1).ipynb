# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

import sklearn
from scipy import stats
import imblearn

import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (16,5)
plt.style.use('fivethirtyeight')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
df = pd.read_csv('train.csv')
dft = pd.read_csv('test.csv')

# %%
print("The shape of training Data is: ", df.shape)

print("The shape of training Data is: ", dft.shape)
# Out:
# The shape of training Data is:  (54808, 14)
# The shape of training Data is:  (23490, 13)

# %%
df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
dft.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score'],
#       dtype='object')

# %%
df.describe().style.background_gradient(cmap='PuBu', low=0, high=0, axis=0, subset=None, text_color_threshold=0.408, vmin=None, vmax=None)
# Out:
# <style  type="text/css" >
# #T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col0{
#             background-color:  #187cb6;
#             color:  #000000;
#         }#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col1,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col2,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col3,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col4,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col5,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col6,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col7,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col8,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row7_col0{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col0,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row5_col0{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col1,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col2,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col3,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col4,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col5,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col6,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col7,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col8,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col1,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col2,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col3,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col4,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col5,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col6,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col7,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col8,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row3_col0,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row3_col1,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row3_col2,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row3_col3,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row3_col4,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row3_col5,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row3_col6,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row3_col7,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row3_col8,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row4_col1,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row4_col2,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row4_col3,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row4_col4,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row4_col5,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row4_col6,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row4_col7,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row4_col8,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row5_col1,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row5_col2,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row5_col3,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row5_col4,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row5_col5,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row5_col6,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row5_col7,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row5_col8,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row6_col1,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row6_col2,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row6_col3,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row6_col4,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row6_col5,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row6_col6,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row6_col7,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row6_col8,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row7_col1,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row7_col2,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row7_col3,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row7_col4,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row7_col5,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row7_col6,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row7_col7,#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row7_col8{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col0{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row4_col0{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row6_col0{
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }</style><table id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >employee_id</th>        <th class="col_heading level0 col1" >no_of_trainings</th>        <th class="col_heading level0 col2" >age</th>        <th class="col_heading level0 col3" >previous_year_rating</th>        <th class="col_heading level0 col4" >length_of_service</th>        <th class="col_heading level0 col5" >KPIs_met >80%</th>        <th class="col_heading level0 col6" >awards_won?</th>        <th class="col_heading level0 col7" >avg_training_score</th>        <th class="col_heading level0 col8" >is_promoted</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col0" class="data row0 col0" >54808.000000</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col1" class="data row0 col1" >54808.000000</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col2" class="data row0 col2" >54808.000000</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col3" class="data row0 col3" >50684.000000</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col4" class="data row0 col4" >54808.000000</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col5" class="data row0 col5" >54808.000000</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col6" class="data row0 col6" >54808.000000</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col7" class="data row0 col7" >54808.000000</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row0_col8" class="data row0 col8" >54808.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col0" class="data row1 col0" >39195.830627</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col1" class="data row1 col1" >1.253011</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col2" class="data row1 col2" >34.803915</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col3" class="data row1 col3" >3.329256</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col4" class="data row1 col4" >5.865512</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col5" class="data row1 col5" >0.351974</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col6" class="data row1 col6" >0.023172</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col7" class="data row1 col7" >63.386750</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row1_col8" class="data row1 col8" >0.085170</td>
#             </tr>
#             <tr>
#                         <th id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col0" class="data row2 col0" >22586.581449</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col1" class="data row2 col1" >0.609264</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col2" class="data row2 col2" >7.660169</td>
#                         <td id="T_7400d5fc_cb6e_11eb_ba12_0242ac1c0002row2_col3" class="data row2 col3" >1.259993</td>
#                         <td id="T_7400d5fc_cb6e_11eb

# %%
df.describe(include="object")
# Out:
#                department    region   education gender recruitment_channel
# count               54808     54808       52399  54808               54808
# unique                  9        34           3      2                   3
# top     Sales & Marketing  region_2  Bachelor's      m               other
# freq                16840     12343       36669  38496               30446

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 5.9+ MB

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23490 entries, 0 to 23489
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           23490 non-null  int64
#  1   department            23490 non-null  object
#  2   region                23490 non-null  object
#  3   education             22456 non-null  object
#  4   gender                23490 non-null  object
#  5   recruitment_channel   23490 non-null  object
#  6   no_of_trainings       23490 non-null  int64
#  7   age                   23490 non-null  int64
#  8   previous_year_rating  21678 non-null  float64
#  9   length_of_service     23490 non-null  int64
#  10  KPIs_met >80%         23490 non-null  int64
#  11  awards_won?           23490 non-null  int64
#  12  avg_training_score    23490 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 2.3+ MB

# %%
df.head(10)
# Out:
#    employee_id         department  ... avg_training_score is_promoted
# 0        65438  Sales & Marketing  ...                 49           0
# 1        65141         Operations  ...                 60           0
# 2         7513  Sales & Marketing  ...                 50           0
# 3         2542  Sales & Marketing  ...                 50           0
# 4        48945         Technology  ...                 73           0
# 5        58896          Analytics  ...                 85           0
# 6        20379         Operations  ...                 59           0
# 7        16290         Operations  ...                 63           0
# 8        73202          Analytics  ...                 83           0
# 9        28911  Sales & Marketing  ...                 54           0
#
# [10 rows x 14 columns]

# %%
df.tail(10)
# Out:
#        employee_id         department  ... avg_training_score is_promoted
# 54798        40257  Sales & Marketing  ...                 51           0
# 54799        68093        Procurement  ...                 67           0
# 54800        39227                 HR  ...                 52           0
# 54801        12431         Technology  ...                 78           0
# 54802         6915  Sales & Marketing  ...                 49           0
# 54803         3030         Technology  ...                 78           0
# 54804        74592         Operations  ...                 56           0
# 54805        13918          Analytics  ...                 79           0
# 54806        13614  Sales & Marketing  ...                 45           0
# 54807        51526                 HR  ...                 49           0
#
# [10 rows x 14 columns]

# %%
dft.head(10)
# Out:
#    employee_id         department  ... awards_won? avg_training_score
# 0         8724         Technology  ...           0                 77
# 1        74430                 HR  ...           0                 51
# 2        72255  Sales & Marketing  ...           0                 47
# 3        38562        Procurement  ...           0                 65
# 4        64486            Finance  ...           0                 61
# 5        46232        Procurement  ...           0                 68
# 6        54542            Finance  ...           0                 57
# 7        67269          Analytics  ...           0                 85
# 8        66174         Technology  ...           0                 75
# 9        76303         Technology  ...           0                 76
#
# [10 rows x 13 columns]

# %%
dft.tail(10)
# Out:
#        employee_id         department  ... awards_won? avg_training_score
# 23480        11837         Operations  ...           0                 60
# 23481        78278         Operations  ...           0                 60
# 23482        27284  Sales & Marketing  ...           0                 49
# 23483        49291  Sales & Marketing  ...           0                 49
# 23484        47537  Sales & Marketing  ...           0                 51
# 23485        53478              Legal  ...           0                 61
# 23486        25600         Technology  ...           0                 74
# 23487        45409                 HR  ...           0                 50
# 23488         1186        Procurement  ...           0                 70
# 23489         5973         Technology  ...           0                 89
#
# [10 rows x 13 columns]

# %%
def inspect_data(data):
    return pd.DataFrame({"Data Type":data.dtypes,"No of Levels":data.apply(lambda x: x.nunique(),axis=0), "Levels":data.apply(lambda x: str(x.unique()),axis=0)})
inspect_data(df)
# Out:
#                      Data Type  ...                                             Levels
# employee_id              int64  ...          [65438 65141  7513 ... 13918 13614 51526]
# department              object  ...  ['Sales & Marketing' 'Operations' 'Technology'...
# region                  object  ...  ['region_7' 'region_22' 'region_19' 'region_23...
# education               object  ...  ["Master's & above" "Bachelor's" nan 'Below Se...
# gender                  object  ...                                          ['f' 'm']
# recruitment_channel     object  ...                    ['sourcing' 'other' 'referred']
# no_of_trainings          int64  ...                    [ 1  2  3  4  7  5  6  8 10  9]
# age                      int64  ...  [35 30 34 39 45 31 33 28 32 49 37 38 41 27 29 ...
# previous_year_rating   float64  ...                          [ 5.  3.  1.  4. nan  2.]
# length_of_service        int64  ...  [ 8  4  7 10  2  5  6  1  3 16  9 11 26 12 17 ...
# KPIs_met >80%            int64  ...                                              [1 0]
# awards_won?              int64  ...                                              [0 1]
# avg_training_score       int64  ...  [49 60 50 73 85 59 63 83 54 77 80 84 51 46 75 ...
# is_promoted              int64  ...                                              [0 1]
#
# [14 rows x 3 columns]

# %%
df.dtypes
# Out:
# employee_id               int64
# department               object
# region                   object
# education                object
# gender                   object
# recruitment_channel      object
# no_of_trainings           int64
# age                       int64
# previous_year_rating    float64
# length_of_service         int64
# KPIs_met >80%             int64
# awards_won?               int64
# avg_training_score        int64
# is_promoted               int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum(axis=0)
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
df_total = df.isnull().sum()

df_percent = ((df.isnull().sum()/df.shape[0])*100).round(2)

dft_total = dft.isnull().sum()

dft_percent = ((dft.isnull().sum()/dft.shape[0])*100).round(2)

df_missing_data = pd.concat([df_total, df_percent, dft_total, dft_percent],
                                axis=1, 
                                keys=['df_Total', 'df_Percent %','dft_Total', 'dft_Percent %'],
                                sort = True)

df_missing_data.style.bar(color = ['green'])
# Out:
# <style  type="text/css" >
# #T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row0_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row0_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row0_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row0_col3,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row1_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row1_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row1_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row1_col3,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row2_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row2_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row2_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row2_col3,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row3_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row3_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row3_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row3_col3,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row4_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row4_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row4_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row4_col3,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row6_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row6_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row6_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row6_col3,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row7_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row7_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row7_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row7_col3,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row8_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row8_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row9_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row9_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row9_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row9_col3,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row10_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row10_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row10_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row10_col3,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row12_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row12_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row12_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row12_col3,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row13_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row13_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row13_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row13_col3{
#             width:  10em;
#              height:  80%;
#         }#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 58.4%, transparent 58.4%);
#         }#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 58.5%, transparent 58.5%);
#         }#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row5_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 57.1%, transparent 57.1%);
#         }#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row11_col0,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row11_col1,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row11_col2,#T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row11_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 100.0%, transparent 100.0%);
#         }</style><table id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >df_Total</th>        <th class="col_heading level0 col1" >df_Percent %</th>        <th class="col_heading level0 col2" >dft_Total</th>        <th class="col_heading level0 col3" >dft_Percent %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002level0_row0" class="row_heading level0 row0" >KPIs_met >80%</th>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row0_col3" class="data row0 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002level0_row1" class="row_heading level0 row1" >age</th>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row1_col3" class="data row1 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002level0_row2" class="row_heading level0 row2" >avg_training_score</th>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row2_col0" class="data row2 col0" >0</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row2_col2" class="data row2 col2" >0.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row2_col3" class="data row2 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002level0_row3" class="row_heading level0 row3" >awards_won?</th>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row3_col2" class="data row3 col2" >0.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row3_col3" class="data row3 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002level0_row4" class="row_heading level0 row4" >department</th>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row4_col1" class="data row4 col1" >0.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row4_col2" class="data row4 col2" >0.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row4_col3" class="data row4 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002level0_row5" class="row_heading level0 row5" >education</th>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row5_col0" class="data row5 col0" >2409</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row5_col1" class="data row5 col1" >4.400000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row5_col2" class="data row5 col2" >1034.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row5_col3" class="data row5 col3" >4.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002level0_row6" class="row_heading level0 row6" >employee_id</th>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row6_col1" class="data row6 col1" >0.000000</td>
#                         <td id="T_745c3b22_cb6e_11eb_ba12_0242ac1c0002row6_col2" cl

# %%
msno.matrix(df.drop('employee_id', axis='columns').sample(500))
plt.show()

# %%
msno.bar(df.drop('employee_id', axis='columns'))
plt.show()

# %%
msno.matrix(dft.drop('employee_id', axis='columns').sample(500))
plt.show()

# %%
msno.bar(dft.drop('employee_id', axis='columns'))
plt.show()

# %%
df['education'] = df['education'].fillna(df['education'].mode()[0])
df['previous_year_rating'] = df['previous_year_rating'].fillna(df['previous_year_rating'].mode()[0])

print("Number of Missing Values Left in the Training Data :", df.isnull().sum().sum())
# Out:
# Number of Missing Values Left in the Training Data : 0

# %%
dft['education'] = dft['education'].fillna(dft['education'].mode()[0])
dft['previous_year_rating'] = dft['previous_year_rating'].fillna(dft['previous_year_rating'].mode()[0])

print("Number of Missing Values Left in the Training Data :", dft.isnull().sum().sum())
# Out:
# Number of Missing Values Left in the Training Data : 0

# %%
msno.matrix(df.drop('employee_id', axis='columns').sample(500))
plt.show()

# %%
msno.bar(df.drop('employee_id', axis='columns'))
plt.show()

# %%
msno.matrix(dft.drop('employee_id', axis='columns').sample(500))
plt.show()

# %%
msno.bar(dft.drop('employee_id', axis='columns'))
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 5)
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
sns.countplot(df['is_promoted'],)

plt.xlabel('Promoted or Not?', fontsize = 15)

plt.subplot(1, 2, 2)
df['is_promoted'].value_counts().plot(kind = 'pie', explode = [0, 0.1], autopct = '%.2f%%', startangle = 90,
                                       labels = ['1','0'], shadow = True, pctdistance = 0.5)
plt.axis('off')

plt.suptitle('Target Class Balance', fontsize = 20)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (14, 6)) 
plt.subplot(1,1,1)
sns.distplot(df["is_promoted"], bins = 20)
plt.show()

# %%
df1 = df[['no_of_trainings', 'age', 'previous_year_rating', 'length_of_service', 'KPIs_met >80%', 'awards_won?', 'avg_training_score', 'is_promoted']]

# %%
df1.head(10)
# Out:
#    no_of_trainings  age  ...  avg_training_score  is_promoted
# 0                1   35  ...                  49            0
# 1                1   30  ...                  60            0
# 2                1   34  ...                  50            0
# 3                2   39  ...                  50            0
# 4                1   45  ...                  73            0
# 5                2   31  ...                  85            0
# 6                1   31  ...                  59            0
# 7                1   33  ...                  63            0
# 8                1   28  ...                  83            0
# 9                1   32  ...                  54            0
#
# [10 rows x 8 columns]

# %%
df1.tail(10)
# Out:
#        no_of_trainings  age  ...  avg_training_score  is_promoted
# 54798                2   40  ...                  51            0
# 54799                1   50  ...                  67            0
# 54800                2   34  ...                  52            0
# 54801                1   31  ...                  78            0
# 54802                2   31  ...                  49            0
# 54803                1   48  ...                  78            0
# 54804                1   37  ...                  56            0
# 54805                1   27  ...                  79            0
# 54806                1   29  ...                  45            0
# 54807                1   27  ...                  49            0
#
# [10 rows x 8 columns]

# %%
sns.pairplot(df1,
             x_vars = [ 'is_promoted', 'no_of_trainings', 'length_of_service', 'KPIs_met >80%', 'awards_won?', 'avg_training_score' ],
             y_vars = [ 'is_promoted', 'no_of_trainings', 'KPIs_met >80%', 'awards_won?' ],
       diag_kind='kde', hue='is_promoted'
             )
plt.show()

# %%
sns.pairplot(df1,
             x_vars = [ 'is_promoted', 'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service', 'KPIs_met >80%', 'awards_won?', 'avg_training_score'],
             y_vars = [ 'is_promoted', 'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service', 'KPIs_met >80%', 'awards_won?', 'avg_training_score' ],
       diag_kind='kde', hue='is_promoted'
             )
plt.show()

# %%
sns.stripplot(y='length_of_service', x='awards_won?', data=df1)

# %%
fig, axarr = plt.subplots(3,2, figsize=(20,20))

sns.stripplot(y='length_of_service', x='awards_won?', data=df1, hue=None, ax=axarr[0][0])
sns.stripplot(y='length_of_service', x='is_promoted', data=df1, hue=None, ax=axarr[1][1])
sns.stripplot(y='previous_year_rating', x='is_promoted', data=df1, hue=None, ax=axarr[1][0])
sns.stripplot(y='KPIs_met >80%', x='is_promoted', data=df1, hue=None,  ax=axarr[0][1])
sns.stripplot(y='avg_training_score', x='is_promoted', data=df1, hue=None, ax=axarr[2][0])
sns.stripplot(y='no_of_trainings', x='is_promoted', data=df1, hue=None, ax=axarr[2][1])
plt.show()

# %%
df.select_dtypes('number').head(50)
# Out:
#     employee_id  no_of_trainings  ...  avg_training_score  is_promoted
# 0         65438                1  ...                  49            0
# 1         65141                1  ...                  60            0
# 2          7513                1  ...                  50            0
# 3          2542                2  ...                  50            0
# 4         48945                1  ...                  73            0
# 5         58896                2  ...                  85            0
# 6         20379                1  ...                  59            0
# 7         16290                1  ...                  63            0
# 8         73202                1  ...                  83            0
# 9         28911                1  ...                  54            0
# 10        29934                1  ...                  77            0
# 11        49017                1  ...                  50            1
# 12        60051                1  ...                  49            0
# 13        38401                2  ...                  80            0
# 14        77040                1  ...                  84            0
# 15        43931                1  ...                  60            0
# 16         7152                1  ...                  77            0
# 17         9403                1  ...                  51            0
# 18        17436                1  ...                  46            0
# 19        54461                1  ...                  59            0
# 20        12067                1  ...                  75            0
# 21        33332                1  ...                  57            0
# 22        58789                1  ...                  63            0
# 23        71177                1  ...                  70            0
# 24        52057                2  ...                  59            0
# 25        26585                1  ...                  83            0
# 26        37749                1  ...                  68            0
# 27         2370                1  ...                  79            0
# 28         8219                1  ...                  80            0
# 29        74759                1  ...                  44            0
# 30        27395                1  ...                  72            0
# 31        58536                2  ...                  61            0
# 32        35465                1  ...                  48            0
# 33        51756                2  ...                  58            0
# 34        57011                2  ...                  87            0
# 35        77064                1  ...                  47            0
# 36        64062                1  ...                  75            0
# 37        47123                1  ...                  47            0
# 38        56275                1  ...                  51            0
# 39        58304                1  ...                  51            1
# 40        25014                1  ...                  80            0
# 41        40097                2  ...                  57            0
# 42        23560                1  ...                  52            0
# 43        17423                3  ...                  48            0
# 44        61758                1  ...                  88            0
# 45        75009                1  ...                  71            0
# 46        17876                1  ...                  71            0
# 47        36924                1  ...                  80            0
# 48        50408                1  ...                  49            0
# 49        18013                1  ...                  73            0
#
# [50 rows x 9 columns]

# %%
plt.rcParams['figure.figsize'] = (15, 5)
plt.style.use('fivethirtyeight')

plt.subplot(1, 5, 1)
sns.boxplot(df['employee_id'], color = 'red')
plt.xlabel('employee id', fontsize = 12)
plt.ylabel('Range', fontsize = 12)

plt.subplot(1, 5, 2)
sns.boxplot(df['no_of_trainings'], color = 'red')
plt.xlabel('no_of_trainings', fontsize = 12)
plt.ylabel('Range', fontsize = 12)

plt.subplot(1, 5, 3)
sns.boxplot(df['age'], color = 'red')
plt.xlabel('age', fontsize = 12)
plt.ylabel('Range', fontsize = 12)

plt.subplot(1, 5, 4)
sns.boxplot(df['previous_year_rating'], color = 'red')
plt.xlabel('previous_year_rating', fontsize = 12)
plt.ylabel('Range', fontsize = 12)

plt.subplot(1, 5, 5)
sns.boxplot(df['length_of_service'], color = 'red')
plt.xlabel('Length of Service', fontsize = 12)
plt.ylabel('Range', fontsize = 12)
# Out:
# Text(0, 0.5, 'Range')

# %%
plt.rcParams['figure.figsize'] = (15, 5)
plt.style.use('fivethirtyeight')

plt.subplot(1, 4, 1)
sns.boxplot(df['KPIs_met >80%'], color = 'red')
plt.xlabel('KPIs_met >80%', fontsize = 12)
plt.ylabel('Range', fontsize = 12)

plt.subplot(1, 4, 2)
sns.boxplot(df['awards_won?'], color = 'red')
plt.xlabel('awards_won?', fontsize = 12)
plt.ylabel('Range', fontsize = 12)

plt.subplot(1, 4, 3)
sns.boxplot(df['avg_training_score'], color = 'red')
plt.xlabel('Average Training Score', fontsize = 12)
plt.ylabel('Range', fontsize = 12)

plt.subplot(1, 4, 4)
sns.boxplot(df['is_promoted'], color = 'red')
plt.xlabel('is_promoted', fontsize = 12)
plt.ylabel('Range', fontsize = 12)
# Out:
# Text(0, 0.5, 'Range')

# %%
df[df['length_of_service'] > 13]
# Out:
#        employee_id         department  ... avg_training_score is_promoted
# 13           38401         Technology  ...                 80           0
# 42           23560                 HR  ...                 52           0
# 60           17673  Sales & Marketing  ...                 47           1
# 74           77577  Sales & Marketing  ...                 52           0
# 99           51256            Finance  ...                 59           0
# ...            ...                ...  ...                ...         ...
# 54691         4210          Analytics  ...                 86           0
# 54695        41348         Operations  ...                 56           1
# 54697        10636  Sales & Marketing  ...                 50           0
# 54754        45697         Technology  ...                 79           0
# 54803         3030         Technology  ...                 78           0
#
# [3489 rows x 14 columns]

# %%
plt.rcParams['figure.figsize'] = (16,5)
plt.style.use('fivethirtyeight')

plt.subplot(1, 3, 1)
labels = ['0','1']
sizes = df['KPIs_met >80%'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 4))
explode = [0, 0]

plt.pie(sizes, labels = labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('KPIs Met > 80%', fontsize = 20)
 
plt.subplot(1, 3, 2)
labels = ['1', '2', '3', '4', '5']
sizes = df['previous_year_rating'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 4))
explode = [0, 0, 0, 0, 0.1]

plt.pie(sizes, labels = labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Previous year Ratings', fontsize = 20)

plt.subplot(1, 3, 3)
labels = ['0', '1']
sizes = df['awards_won?'].value_counts()
colors = plt.cm.Wistia(np.linspace(0, 1, 4))
explode = [0,0.2]

plt.pie(sizes, labels = labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Awards Won?', fontsize = 20)

plt.legend()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (17, 4)
sns.countplot(df['no_of_trainings'], palette = 'husl')
plt.xlabel(' ', fontsize = 15)
plt.title('Distribution of Trainings undertaken by the Employees')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (17, 4)
sns.distplot(df['no_of_trainings'])
plt.show()

# %%
plt.rcParams['figure.figsize'] = (8, 4)
plt.hist(df['age'], color='cyan')
plt.title('Distribution of Age among the Employees', fontsize = 15, c='m')
plt.xlabel('Age of the Employees', color='blue')
plt.grid()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (12, 6)
sns.countplot(y = df['department'], palette = 'gist_stern_r', orient = 'v')
plt.xlabel('')
plt.ylabel('Department Name', fontsize=15, fontweight=2, color='red')
plt.title('Distribution of Employees in Different Departments', fontsize = 20, fontweight = 2, color='green')
plt.grid()

plt.show()

# %%
plt.rcParams['figure.figsize'] = (12,15)
plt.style.use('fivethirtyeight')
sns.countplot(y = df['region'], palette = 'inferno', orient = 'v')
plt.xlabel('')
plt.ylabel('Region',color='red', fontweight=2)
plt.title('Different Regions', fontsize = 20, color="brown", fontweight=2)
plt.xticks(rotation = 45)
plt.yticks(rotation = 30)
plt.grid()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (16,5)

plt.subplot(1, 3, 1)
labels = df['education'].value_counts().index
print(labels)
sizes = df['education'].value_counts()
colors = plt.cm.copper(np.linspace(0, 1, 5))
explode = [0, 0, 0.1]

plt.pie(sizes, labels = labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Education', fontsize = 20)

plt.subplot(1, 3, 2)
labels = df['gender'].value_counts().index
sizes = df['gender'].value_counts()
colors = plt.cm.copper(np.linspace(0, 1, 5))
explode = [0, 0.1]

plt.pie(sizes, labels = labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Gender', fontsize = 20)

plt.subplot(1, 3, 3)
labels = df['recruitment_channel'].value_counts().index
sizes = df['recruitment_channel'].value_counts()
colors = plt.cm.copper(np.linspace(0, 1, 5))
explode = [0, 0, 0.1]

plt.pie(sizes, labels = labels, colors = colors, explode = explode, shadow = True, startangle = 90)
plt.title('Recruitment Channel', fontsize = 20)

plt.show()
# Out:
# Index(['Bachelor's', 'Master's & above', 'Below Secondary'], dtype='object')

# %%
df2 = df1[['previous_year_rating', 'is_promoted']]
df2.head(10)
# Out:
#    previous_year_rating  is_promoted
# 0                   5.0            0
# 1                   5.0            0
# 2                   3.0            0
# 3                   1.0            0
# 4                   3.0            0
# 5                   3.0            0
# 6                   3.0            0
# 7                   3.0            0
# 8                   4.0            0
# 9                   5.0            0

# %%
df2.tail(10)
# Out:
#        previous_year_rating  is_promoted
# 54798                   5.0            0
# 54799                   5.0            0
# 54800                   5.0            0
# 54801                   3.0            0
# 54802                   1.0            0
# 54803                   3.0            0
# 54804                   2.0            0
# 54805                   5.0            0
# 54806                   1.0            0
# 54807                   1.0            0

# %%
sns.pairplot(df2,
             x_vars = ['previous_year_rating', 'is_promoted'],
             y_vars =  ['previous_year_rating', 'is_promoted'],
       diag_kind='kde'
             )

# %%
dftrain = df2.sample(frac=0.8, random_state=0) 
dftest = df2.drop(dftrain.index)

print(dftrain.head(10))
print(dftest.head(10))
# Out:
#        previous_year_rating  is_promoted
# 28686                   3.0            0
# 16191                   4.0            0
# 12951                   3.0            0
# 7890                    5.0            1
# 29387                   3.0            0
# 49407                   3.0            0
# 6826                    5.0            0
# 44010                   3.0            0
# 43286                   4.0            0
# 918                     1.0            0
#     previous_year_rating  is_promoted
# 10                   3.0            0
# 11                   5.0            1
# 13                   3.0            0
# 19                   3.0            0
# 21                   4.0            0
# 26                   5.0            0
# 30                   5.0            0
# 41                   4.0            0
# 43                   2.0            0
# 49                   3.0            0

# %%
print(dftrain.shape)
print(dftest.shape)
# Out:
# (43846, 2)
# (10962, 2)

# %%
dftrain = dftrain.copy()
dftest = dftest.copy()

print(dftrain.head(10))
print(dftest.head(10))
# Out:
#        previous_year_rating  is_promoted
# 28686                   3.0            0
# 16191                   4.0            0
# 12951                   3.0            0
# 7890                    5.0            1
# 29387                   3.0            0
# 49407                   3.0            0
# 6826                    5.0            0
# 44010                   3.0            0
# 43286                   4.0            0
# 918                     1.0            0
#     previous_year_rating  is_promoted
# 10                   3.0            0
# 11                   5.0            1
# 13                   3.0            0
# 19                   3.0            0
# 21                   4.0            0
# 26                   5.0            0
# 30                   5.0            0
# 41                   4.0            0
# 43                   2.0            0
# 49                   3.0            0

# %%
dftr = dftrain.pop('is_promoted')
dfte = dftest.pop('is_promoted')

print(dftr.head(10))
print(dfte.head(10))
# Out:
# 28686    0
# 16191    0
# 12951    0
# 7890     1
# 29387    0
# 49407    0
# 6826     0
# 44010    0
# 43286    0
# 918      0
# Name: is_promoted, dtype: int64
# 10    0
# 11    1
# 13    0
# 19    0
# 21    0
# 26    0
# 30    0
# 41    0
# 43    0
# 49    0
# Name: is_promoted, dtype: int64

# %%
print(dftrain.head())
print(dftest.head())
# Out:
#        previous_year_rating
# 28686                   3.0
# 16191                   4.0
# 12951                   3.0
# 7890                    5.0
# 29387                   3.0
#     previous_year_rating
# 10                   3.0
# 11                   5.0
# 13                   3.0
# 19                   3.0
# 21                   4.0

# %%
import tensorflow as tf 
from tensorflow import keras

model = tf.keras.Sequential([
                             tf.keras.layers.Dense(1)

])

# %%
model.compile(
    loss = 'mean_absolute_error',
    optimizer = tf.keras.optimizers.Adam(0.001),
    metrics = ['mae', 'mse']
)

# %%
numEpochs = 3000
history = model.fit(x = dftrain, y = dftr, validation_data = (dftest, dfte), epochs = numEpochs)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 501/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 502/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 503/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 504/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 505/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 506/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0847
# Epoch 507/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 508/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0863 - val_mae: 0.0863 - val_mse: 0.0845
# Epoch 509/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0847
# Epoch 510/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 511/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0858 - mae: 0.0858 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0846
# Epoch 512/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 513/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 514/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 515/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 516/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 517/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 518/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 519/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0850
# Epoch 520/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0859 - val_mae: 0.0859 - val_mse: 0.0850
# Epoch 521/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0861 - val_mae: 0.0861 - val_mse: 0.0851
# Epoch 522/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0850
# Epoch 523/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 524/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0846
# Epoch 525/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0850
# Epoch 526/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 527/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 528/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0846
# Epoch 529/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 530/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0858 - mae: 0.0858 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 531/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 532/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 533/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 534/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0850
# Epoch 535/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 536/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 537/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 538/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 539/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 540/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0863 - val_mae: 0.0863 - val_mse: 0.0845
# Epoch 541/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 542/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 543/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 544/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 545/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0858 - val_mae: 0.0858 - val_mse: 0.0846
# Epoch 546/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0849
# Epoch 547/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 548/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 549/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 550/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0858 - mae: 0.0858 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 551/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0846
# Epoch 552/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 553/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0847
# Epoch 554/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 555/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 556/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 557/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 558/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 559/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0846
# Epoch 560/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0849
# Epoch 561/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 562/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0849
# Epoch 563/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 564/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 565/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0858 - mae: 0.0858 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 566/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 567/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0847
# Epoch 568/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 569/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0858 - mae: 0.0858 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 570/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 571/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 572/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 573/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0849
# Epoch 574/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 575/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0847
# Epoch 576/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 577/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 578/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0848 - val_mae: 0.0848 - val_mse: 0.0848
# Epoch 579/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 580/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 581/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 582/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 583/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0849
# Epoch 584/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 585/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 586/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 587/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 588/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 589/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 590/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 591/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 592/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 593/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0850
# Epoch 594/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0846
# Epoch 595/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0850
# Epoch 596/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 597/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0850
# Epoch 598/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 599/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 600/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0860 - val_mae: 0.0860 - val_mse: 0.0851
# Epoch 601/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 602/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 603/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 604/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 605/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0850
# Epoch 606/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0859 - val_mae: 0.0859 - val_mse: 0.0846
# Epoch 607/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 608/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 609/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0846
# Epoch 610/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 611/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 612/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 613/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 614/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 615/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 616/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 617/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 618/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 619/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 620/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 621/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 622/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 623/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 624/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0859 - val_mae: 0.0859 - val_mse: 0.0850
# Epoch 625/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 626/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0849
# Epoch 627/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 628/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 629/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 630/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 631/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0861 - val_mae: 0.0861 - val_mse: 0.0851
# Epoch 632/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 633/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 634/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 635/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 636/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 637/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 638/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0858 - mae: 0.0858 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 639/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 640/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0849
# Epoch 641/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 642/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0846
# Epoch 643/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 644/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 645/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 646/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 647/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 648/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 649/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0858 - val_mae: 0.0858 - val_mse: 0.0846
# Epoch 650/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 651/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 652/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0859 - val_mae: 0.0859 - val_mse: 0.0850
# Epoch 653/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 654/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 655/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0847
# Epoch 656/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 657/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 658/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 659/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0849
# Epoch 660/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0849
# Epoch 661/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 662/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 663/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 664/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 665/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 666/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 667/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 668/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 669/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0850
# Epoch 670/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 671/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0859 - val_mae: 0.0859 - val_mse: 0.0846
# Epoch 672/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0850
# Epoch 673/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 674/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 675/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 676/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 677/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 678/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 679/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0849
# Epoch 680/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 681/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 682/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 683/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 684/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 685/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 686/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 687/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 688/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0861 - val_mae: 0.0861 - val_mse: 0.0851
# Epoch 689/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 690/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 691/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0847
# Epoch 692/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 693/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 694/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0850
# Epoch 695/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 696/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0847
# Epoch 697/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 698/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 699/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0849
# Epoch 700/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 701/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0846
# Epoch 702/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0861 - val_mae: 0.0861 - val_mse: 0.0851
# Epoch 703/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 704/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 705/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 706/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0859 - val_mae: 0.0859 - val_mse: 0.0846
# Epoch 707/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0849
# Epoch 708/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 709/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 710/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 711/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 712/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 713/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 714/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 715/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 716/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0846
# Epoch 717/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 718/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0865 - val_mae: 0.0865 - val_mse: 0.0852
# Epoch 719/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0846
# Epoch 720/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 721/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0847
# Epoch 722/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0862 - val_mae: 0.0862 - val_mse: 0.0845
# Epoch 723/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 724/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 725/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 726/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 727/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 728/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 729/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0847
# Epoch 730/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0861 - val_mae: 0.0861 - val_mse: 0.0845
# Epoch 731/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0860 - val_mae: 0.0860 - val_mse: 0.0846
# Epoch 732/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 733/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 734/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0847
# Epoch 735/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 736/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 737/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 738/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0864 - val_mae: 0.0864 - val_mse: 0.0845
# Epoch 739/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 740/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 741/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 742/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 743/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0850
# Epoch 744/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0850
# Epoch 745/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 746/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 747/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 748/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0858 - val_mae: 0.0858 - val_mse: 0.0850
# Epoch 749/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 750/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 751/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 752/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 753/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0858 - val_mae: 0.0858 - val_mse: 0.0846
# Epoch 754/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0847
# Epoch 755/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0858 - val_mae: 0.0858 - val_mse: 0.0850
# Epoch 756/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 757/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0859 - val_mae: 0.0859 - val_mse: 0.0846
# Epoch 758/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 759/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 760/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 761/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 762/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 763/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 764/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0846
# Epoch 765/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 766/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 767/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 768/3000
# 1371/1371 [==============================] - 2s 1ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0858 - val_mae: 0.0858 - val_mse: 0.0846
# Epoch 769/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 770/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 771/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 772/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 773/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 774/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 775/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0850
# Epoch 776/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 777/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 778/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0849
# Epoch 779/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0858 - mae: 0.0858 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 780/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 781/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0858 - val_mae: 0.0858 - val_mse: 0.0846
# Epoch 782/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# ...
# Epoch 2908/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0847
# Epoch 2909/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0847
# Epoch 2910/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 2911/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0859 - val_mae: 0.0859 - val_mse: 0.0850
# Epoch 2912/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 2913/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0848 - val_mae: 0.0848 - val_mse: 0.0848
# Epoch 2914/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0850
# Epoch 2915/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 2916/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 2917/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0859 - val_mae: 0.0859 - val_mse: 0.0846
# Epoch 2918/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 2919/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0850
# Epoch 2920/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 2921/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0847
# Epoch 2922/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 2923/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 2924/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 2925/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0858 - val_mae: 0.0858 - val_mse: 0.0846
# Epoch 2926/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0850
# Epoch 2927/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0860 - val_mae: 0.0860 - val_mse: 0.0846
# Epoch 2928/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2929/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 2930/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 2931/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 2932/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 2933/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 2934/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 2935/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 2936/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0861 - val_mae: 0.0861 - val_mse: 0.0845
# Epoch 2937/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0858 - val_mae: 0.0858 - val_mse: 0.0850
# Epoch 2938/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 2939/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0850
# Epoch 2940/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2941/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2942/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0846
# Epoch 2943/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 2944/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0858 - val_mae: 0.0858 - val_mse: 0.0846
# Epoch 2945/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0859 - val_mae: 0.0859 - val_mse: 0.0850
# Epoch 2946/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 2947/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0848
# Epoch 2948/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 2949/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0849
# Epoch 2950/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 2951/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0866 - val_mae: 0.0866 - val_mse: 0.0852
# Epoch 2952/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2953/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0846
# Epoch 2954/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0850
# Epoch 2955/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0847
# Epoch 2956/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 2957/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2958/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 2959/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2960/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 2961/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 2962/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 2963/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0850
# Epoch 2964/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2965/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 2966/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0858 - val_mae: 0.0858 - val_mse: 0.0846
# Epoch 2967/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 2968/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 2969/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 2970/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2971/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2972/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 2973/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 2974/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2975/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 2976/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0849
# Epoch 2977/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0862 - val_mae: 0.0862 - val_mse: 0.0845
# Epoch 2978/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0860 - val_mae: 0.0860 - val_mse: 0.0846
# Epoch 2979/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2980/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2981/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0850
# Epoch 2982/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 2983/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0850
# Epoch 2984/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 2985/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0849
# Epoch 2986/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 2987/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 2988/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0850
# Epoch 2989/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0857 - val_mae: 0.0857 - val_mse: 0.0850
# Epoch 2990/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0856 - val_mae: 0.0856 - val_mse: 0.0846
# Epoch 2991/3000
# 1371/1371 [==============================] - 2s 2ms/step - loss: 0.0856 - mae: 0.0856 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2992/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0847
# Epoch 2993/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0855 - val_mae: 0.0855 - val_mse: 0.0850
# Epoch 2994/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0854 - val_mae: 0.0854 - val_mse: 0.0847
# Epoch 2995/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0852 - val_mae: 0.0852 - val_mse: 0.0849
# Epoch 2996/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848
# Epoch 2997/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0851 - val_mae: 0.0851 - val_mse: 0.0848
# Epoch 2998/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0850 - val_mae: 0.0850 - val_mse: 0.0848
# Epoch 2999/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0853 - val_mae: 0.0853 - val_mse: 0.0847
# Epoch 3000/3000
# 1371/1371 [==============================] - 3s 2ms/step - loss: 0.0857 - mae: 0.0857 - mse: 0.0852 - val_loss: 0.0849 - val_mae: 0.0849 - val_mse: 0.0848

# %%
print(history)
# Out:
# <tensorflow.python.keras.callbacks.History object at 0x7f10b0c0bbd0>

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
def curvePlots(tempString):
  plt.plot(history.history[tempString])
  plt.plot(history.history[f'val_{tempString}'])
  plt.xlabel('NumEpochs')
  plt.ylabel(tempString)
  plt.legend([tempString, f'val_{tempString}'])
  plt.show()


curvePlots('mse')
curvePlots('mae')
curvePlots('loss')

# %%
model.predict([3])
# Out:
# array([[-7.2996656e-05]], dtype=float32)

# %%
print(f'Prediction for employee rating 3: {model.predict([3])}')

tempListforPreds = [1,2,3,4,5]
print(f'''

input List = {tempListforPreds}


List of Predictions:
{model.predict(tempListforPreds)}

List of Predictions (flattened out):
{model.predict(tempListforPreds).flatten()}
''')
# Out:
# Prediction for employee rating 3: [[-7.2996656e-05]]
#
#
# input List = [1, 2, 3, 4, 5]
#
#
# List of Predictions:
# [[-1.7951967e-04]
#  [-1.2625816e-04]
#  [-7.2996656e-05]
#  [-1.9735162e-05]
#  [ 3.3526332e-05]]
#
# List of Predictions (flattened out):
# [-1.7951967e-04 -1.2625816e-04 -7.2996656e-05 -1.9735162e-05
#   3.3526332e-05]

# %%
print(dftest)
# Out:
#        previous_year_rating
# 10                      3.0
# 11                      5.0
# 13                      3.0
# 19                      3.0
# 21                      4.0
# ...                     ...
# 54769                   1.0
# 54770                   3.0
# 54781                   5.0
# 54784                   5.0
# 54801                   3.0
#
# [10962 rows x 1 columns]

# %%
pred = model.predict(dftest).flatten()

# %%
print(len(pred))
print(pred)
# Out:
# 10962
# [-7.2996656e-05  3.3526332e-05 -7.2996656e-05 ...  3.3526332e-05
#   3.3526332e-05 -7.2996656e-05]

# %%
def predPlot(labels, predictions):
  plt.scatter(labels, predictions)
  plt.ylabel('Predictions')
  plt.xlabel('True Value or Labels')
  plt.axis('equal')
  plt.axis('square')
  plt.xlim([0, plt.xlim()[1]])
  plt.ylim([0, plt.ylim()[1]])
  plt.show()

predPlot(dfte, pred)

# %%
def errorPlot(preds, labels, counts):
  errors = preds - labels
  plt.hist(errors, counts)
  plt.xlabel('Error')
  plt.ylabel('Counts')
  plt.show()

errorPlot(pred, dfte, numEpochs)
